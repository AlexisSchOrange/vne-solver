# %%
using Revise
includet("utils/file_reader.jl")
includet("utils/some_data.jl")
includet("utils/utils_graph.jl")
includet("resolution/compact/compact_formulation.jl")
includet("resolution/path/path_generation.jl")
includet("utils/visu.jl")

# %%
instance = get_instance_from_folder("instances/")
# Out:
# InstanceVNE(Any[Meta graph based on a SimpleDiGraph{Int64} with vertex labels of type Int64, vertex metadata of type Dict, edge metadata of type Dict, graph metadata given by Dict(:type => "virtual", :name => "virt"), and default weight 1.0], Meta graph based on a SimpleDiGraph{Int64} with vertex labels of type Int64, vertex metadata of type Dict, edge metadata of type Dict, graph metadata given by Dict(:type => "substrate", :name => "Aarnet"), and default weight 1.0)

# %%
visu_graph(instance.v_networks[1])

# %%
print_virtual(instance.v_networks[1])
# Out:
# Metagraph
# Node 1 with dem 1
# Node 2 with dem 1
# Node 3 with dem 1
# Node 4 with dem 1
# Node 5 with dem 1
# Node 6 with dem 1
# Node 7 with dem 1
# Edge Edge 1 => 2 with dem 1
# Edge Edge 1 => 3 with dem 1
# Edge Edge 1 => 4 with dem 1
# Edge Edge 2 => 3 with dem 1
# Edge Edge 3 => 4 with dem 1
# Edge Edge 3 => 7 with dem 1
# Edge Edge 4 => 2 with dem 1
# Edge Edge 4 => 5 with dem 1
# Edge Edge 5 => 2 with dem 1
# Edge Edge 5 => 4 with dem 1
# Edge Edge 5 => 7 with dem 1
# Edge Edge 6 => 2 with dem 1
# Edge Edge 6 => 3 with dem 1
# Edge Edge 6 => 7 with dem 1
# Edge Edge 7 => 2 with dem 1
# Edge Edge 7 => 5 with dem 1

# %%
visu_graph(instance.s_network)

# %%
print_substrate(instance.s_network)
# Out:
# Metagraph
# Node 1 with cap 1 and cost 1
# Node 2 with cap 1 and cost 1
# Node 3 with cap 1 and cost 1
# Node 4 with cap 1 and cost 1
# Node 5 with cap 1 and cost 1
# Node 6 with cap 1 and cost 1
# Node 7 with cap 1 and cost 1
# Node 8 with cap 1 and cost 1
# Node 9 with cap 1 and cost 1
# Node 10 with cap 1 and cost 1
# Node 11 with cap 1 and cost 1
# Node 12 with cap 1 and cost 1
# Node 13 with cap 1 and cost 1
# Node 14 with cap 1 and cost 1
# Node 15 with cap 1 and cost 1
# Node 16 with cap 1 and cost 1
# Node 17 with cap 1 and cost 1
# Node 18 with cap 1 and cost 1
# Node 19 with cap 1 and cost 1
# Edge Edge 1 => 4 with cap 4 and cost 1
# Edge Edge 1 => 7 with cap 4 and cost 1
# Edge Edge 1 => 11 with cap 4 and cost 1
# Edge Edge 2 => 4 with cap 4 and cost 1
# Edge Edge 2 => 7 with cap 4 and cost 1
# Edge Edge 3 => 11 with cap 4 and cost 1
# Edge Edge 3 => 16 with cap 4 and cost 1
# Edge Edge 4 => 1 with cap 4 and cost 1
# Edge Edge 4 => 2 with cap 5 and cost 1
# Edge Edge 4 => 9 with cap 5 and cost 1
# Edge Edge 4 => 17 with cap 5 and cost 1
# Edge Edge 5 => 6 with cap 5 and cost 1
# Edge Edge 5 => 8 with cap 5 and cost 1
# Edge Edge 7 => 8 with cap 5 and cost 1
# Edge Edge 8 => 5 with cap 5 and cost 1
# Edge Edge 8 => 7 with cap 4 and cost 1
# Edge Edge 9 => 4 with cap 5 and cost 1
# Edge Edge 10 => 16 with cap 5 and cost 1
# Edge Edge 10 => 17 with cap 5 and cost 1
# Edge Edge 11 => 1 with cap 5 and cost 1
# Edge Edge 11 => 3 with cap 5 and cost 1
# Edge Edge 12 => 13 with cap 5 and cost 1
# Edge Edge 12 => 14 with cap 5 and cost 1
# Edge Edge 13 => 15 with cap 5 and cost 1
# Edge Edge 14 => 12 with cap 5 and cost 1
# Edge Edge 14 => 15 with cap 5 and cost 1
# Edge Edge 14 => 16 with cap 5 and cost 1
# Edge Edge 14 => 19 with cap 5 and cost 1
# Edge Edge 15 => 17 with cap 5 and cost 1
# Edge Edge 15 => 18 with cap 5 and cost 1
# Edge Edge 16 => 14 with cap 5 and cost 1
# Edge Edge 16 => 17 with cap 4 and cost 1
# Edge Edge 17 => 4 with cap 3 and cost 1
# Edge Edge 17 => 10 with cap 5 and cost 1
# Edge Edge 18 => 15 with cap 5 and cost 1
# Edge Edge 18 => 19 with cap 5 and cost 1
# Edge Edge 19 => 18 with cap 5 and cost 1

# %%
solve_compact_fractional(instance)
# Out:
# Constructing compact model...CPLEX Error  3003: Not a mixed-integer problem.
# Version identifier: 22.1.1.0 | 2022-11-28 | 9160aff4d
# CPXPARAM_TimeLimit                               10
# CPXPARAM_MIP_Tolerances_Integrality              1e-08
# Tried aggregator 1 time.
# Reduced LP has 367 rows, 725 columns, and 2650 nonzeros.
# Presolve time = 0.00 sec. (0.81 ticks)
# Symmetry aggregator did 432 additional substitutions.
# Initializing dual steep norms . . .
#
# Iteration log . . .
# Iteration:     1   Dual objective     =             5.000000
# Iteration:    62   Dual objective     =             7.000000
#
# Dual crossover.
#   Dual:  Fixing 1 variable.
#         0 DMoves:  Infeasibility  9.54791801e-15  Objective  7.00000000e+00
#   Dual:  Pushed 0, exchanged 1.
#   Primal:  Fixed no variables.
# 1-element Vector{Any}:
#  Node placement of cost : 7.0
# 1 :
#        1 : 0.143
#        5 : 0.143
#        10 : 0.143
#        14 : 0.143
#        15 : 0.143
#        16 : 0.143
#        19 : 0.143
# 2 :
#        1 : 0.143
#        5 : 0.143
#        10 : 0.143
#        14 : 0.143
#        15 : 0.143
#        16 : 0.143
#        19 : 0.143
# 3 :
#        1 : 0.143
#        5 : 0.143
#        10 : 0.143
#        14 : 0.143
#        15 : 0.143
#        16 : 0.143
#        19 : 0.143
# 4 :
#        1 : 0.143
#        5 : 0.143
#        10 : 0.143
#        14 : 0.143
#        15 : 0.143
#        16 : 0.143
#        19 : 0.143
# 5 :
#        1 : 0.143
#        5 : 0.143
#        10 : 0.143
#        14 : 0.143
#        15 : 0.143
#        16 : 0.143
#        19 : 0.143
# 6 :
#        1 : 0.143
#        5 : 0.143
#        10 : 0.143
#        14 : 0.143
#        15 : 0.143
#        16 : 0.143
#        19 : 0.143
# 7 :
#        1 : 0.143
#        5 : 0.143
#        10 : 0.143
#        14 : 0.143
#        15 : 0.143
#        16 : 0.143
#        19 : 0.143
# Edge routing of cost: 0.0
# Edge 1 => 2 :
# Edge 1 => 3 :
# Edge 1 => 4 :
# Edge 2 => 3 :
# Edge 3 => 4 :
# Edge 3 => 7 :
# Edge 4 => 2 :
# Edge 4 => 5 :
# Edge 5 => 2 :
# Edge 5 => 4 :
# Edge 5 => 7 :
# Edge 6 => 2 :
# Edge 6 => 3 :
# Edge 6 => 7 :
# Edge 7 => 2 :
# Edge 7 => 5 :

# %%
solve_compact_fractional(instance, true, true)
# Out:
# Constructing compact model...CPLEX Error  3003: Not a mixed-integer problem.
# Version identifier: 22.1.1.0 | 2022-11-28 | 9160aff4d
# CPXPARAM_TimeLimit                               10
# CPXPARAM_MIP_Tolerances_Integrality              1e-08
# Tried aggregator 1 time.
# LP Presolve eliminated 69 rows and 23 columns.
# Reduced LP has 925 rows, 702 columns, and 4284 nonzeros.
# Presolve time = 0.00 sec. (1.36 ticks)
# Symmetry aggregator did 668 additional substitutions.
# Initializing dual steep norms . . .
#
# Iteration log . . .
# Iteration:     1   Dual objective     =             5.000000
# Iteration:    62   Dual objective     =             7.000000
# Iteration:   124   Dual objective     =            13.666667
# Iteration:   186   Dual objective     =            17.000000
# Iteration:   248   Dual objective     =            19.000000
# Perturbation started.
# Iteration:   306   Dual objective     =            21.000000
# Iteration:   368   Dual objective     =            22.250003
# Iteration:   430   Dual objective     =            23.000001
# Removing perturbation.
#
# Dual crossover.
#   Dual:  Fixing 209 variables.
#       208 DMoves:  Infeasibility  5.59774449e-13  Objective  2.30000000e+01
#        96 DMoves:  Infeasibility  2.37607553e-13  Objective  2.30000000e+01
#         0 DMoves:  Infeasibility  1.94188581e-14  Objective  2.30000000e+01
#   Dual:  Pushed 9, exchanged 200.
#   Primal:  Fixed no variables.
# 1-element Vector{Any}:
#  Node placement of cost : 7.0
# 1 :
#        1 : 0.199
#        4 : 0.197
#        7 : 0.143
#        8 : 0.143
#        11 : 0.002
#        16 : 0.015
#        17 : 0.015
#        18 : 0.143
#        19 : 0.143
# 2 :
#        1 : 0.199
#        4 : 0.197
#        5 : 0.143
#        8 : 0.143
#        10 : 0.015
#        11 : 0.002
#        15 : 0.143
#        17 : 0.015
#        18 : 0.143
# 3 :
#        1 : 0.002
#        2 : 0.197
#        5 : 0.143
#        8 : 0.143
#        10 : 0.015
#        11 : 0.199
#        15 : 0.143
#        17 : 0.015
#        18 : 0.143
# 4 :
#        1 : 0.199
#        4 : 0.197
#        7 : 0.143
#        8 : 0.143
#        10 : 0.015
#        11 : 0.002
#        17 : 0.015
#        18 : 0.143
#        19 : 0.143
# 5 :
#        1 : 0.002
#        2 : 0.197
#        4 : 0.015
#        5 : 0.143
#        8 : 0.143
#        11 : 0.199
#        17 : 0.015
#        18 : 0.143
#        19 : 0.143
# 6 :
#        1 : 0.199
#        4 : 0.197
#        7 : 0.143
#        8 : 0.143
#        11 : 0.002
#        16 : 0.015
#        17 : 0.015
#        18 : 0.143
#        19 : 0.143
# 7 :
#        1 : 0.199
#        4 : 0.197
#        7 : 0.143
#        8 : 0.143
#        10 : 0.015
#        11 : 0.002
#        17 : 0.015
#        18 : 0.143
#        19 : 0.143
# Edge routing of cost: 16.0
# Edge 1 => 2 :
#        0.197 : Edge 1 => 4
#        0.002 : Edge 1 => 11
#        0.197 : Edge 4 => 1
#        0.143 : Edge 7 => 8
#        0.143 : Edge 8 => 5
#        0.002 : Edge 11 => 1
#        0.015 : Edge 16 => 17
#        0.015 : Edge 17 => 10
#        0.143 : Edge 18 => 15
#        0.143 : Edge 19 => 18
# Edge 1 => 3 :
#        0.199 : Edge 1 => 11
#        0.197 : Edge 4 => 2
#        0.143 : Edge 7 => 8
#        0.143 : Edge 8 => 5
#        0.002 : Edge 11 => 1
#        0.015 : Edge 16 => 17
#        0.015 : Edge 17 => 10
#        0.143 : Edge 18 => 15
#        0.143 : Edge 19 => 18
# Edge 1 => 4 :
#        0.197 : Edge 1 => 4
#        0.002 : Edge 1 => 11
#        0.197 : Edge 4 => 1
#        0.143 : Edge 7 => 8
#        0.143 : Edge 8 => 7
#        0.002 : Edge 11 => 1
#        0.015 : Edge 16 => 17
#        0.015 : Edge 17 => 10
#        0.143 : Edge 18 => 19
#        0.143 : Edge 19 => 18
# Edge 2 => 3 :
#        0.199 : Edge 1 => 11
#        0.197 : Edge 4 => 2
#        0.143 : Edge 5 => 8
#        0.143 : Edge 8 => 5
#        0.015 : Edge 10 => 17
#        0.002 : Edge 11 => 1
#        0.143 : Edge 15 => 18
#        0.015 : Edge 17 => 10
#        0.143 : Edge 18 => 15
# Edge 3 => 4 :
#        0.002 : Edge 1 => 11
#        0.197 : Edge 2 => 4
#        0.143 : Edge 5 => 8
#        0.143 : Edge 8 => 7
#        0.015 : Edge 10 => 17
#        0.199 : Edge 11 => 1
#        0.143 : Edge 15 => 18
#        0.015 : Edge 17 => 10
#        0.143 : Edge 18 => 19
# Edge 3 => 7 :
#        0.002 : Edge 1 => 11
#        0.197 : Edge 2 => 4
#        0.143 : Edge 5 => 8
#        0.143 : Edge 8 => 7
#        0.015 : Edge 10 => 17
#        0.199 : Edge 11 => 1
#        0.143 : Edge 15 => 18
#        0.015 : Edge 17 => 10
#        0.143 : Edge 18 => 19
# Edge 4 => 2 :
#        0.197 : Edge 1 => 4
#        0.002 : Edge 1 => 11
#        0.197 : Edge 4 => 1
#        0.143 : Edge 7 => 8
#        0.143 : Edge 8 => 5
#        0.015 : Edge 10 => 17
#        0.002 : Edge 11 => 1
#        0.015 : Edge 17 => 10
#        0.143 : Edge 18 => 15
#        0.143 : Edge 19 => 18
# Edge 4 => 5 :
#        0.199 : Edge 1 => 11
#        0.197 : Edge 4 => 2
#        0.143 : Edge 7 => 8
#        0.143 : Edge 8 => 5
#        0.015 : Edge 10 => 17
#        0.002 : Edge 11 => 1
#        0.015 : Edge 17 => 4
#        0.143 : Edge 18 => 19
#        0.143 : Edge 19 => 18
# Edge 5 => 2 :
#        0.002 : Edge 1 => 11
#        0.197 : Edge 2 => 4
#        0.015 : Edge 4 => 17
#        0.143 : Edge 5 => 8
#        0.143 : Edge 8 => 5
#        0.199 : Edge 11 => 1
#        0.015 : Edge 17 => 10
#        0.143 : Edge 18 => 15
#        0.143 : Edge 19 => 18
# Edge 5 => 4 :
#        0.002 : Edge 1 => 11
#        0.197 : Edge 2 => 4
#        0.015 : Edge 4 => 17
#        0.143 : Edge 5 => 8
#        0.143 : Edge 8 => 7
#        0.199 : Edge 11 => 1
#        0.015 : Edge 17 => 10
#        0.143 : Edge 18 => 19
#        0.143 : Edge 19 => 18
# Edge 5 => 7 :
#        0.002 : Edge 1 => 11
#        0.197 : Edge 2 => 4
#        0.015 : Edge 4 => 17
#        0.143 : Edge 5 => 8
#        0.143 : Edge 8 => 7
#        0.199 : Edge 11 => 1
#        0.015 : Edge 17 => 10
#        0.143 : Edge 18 => 19
#        0.143 : Edge 19 => 18
# Edge 6 => 2 :
#        0.197 : Edge 1 => 4
#        0.002 : Edge 1 => 11
#        0.197 : Edge 4 => 1
#        0.143 : Edge 7 => 8
#        0.143 : Edge 8 => 5
#        0.002 : Edge 11 => 1
#        0.015 : Edge 16 => 17
#        0.015 : Edge 17 => 10
#        0.143 : Edge 18 => 15
#        0.143 : Edge 19 => 18
# Edge 6 => 3 :
#        0.199 : Edge 1 => 11
#        0.197 : Edge 4 => 2
#        0.143 : Edge 7 => 8
#        0.143 : Edge 8 => 5
#        0.002 : Edge 11 => 1
#        0.015 : Edge 16 => 17
#        0.015 : Edge 17 => 10
#        0.143 : Edge 18 => 15
#        0.143 : Edge 19 => 18
# Edge 6 => 7 :
#        0.197 : Edge 1 => 4
#        0.002 : Edge 1 => 11
#        0.197 : Edge 4 => 1
#        0.143 : Edge 7 => 8
#        0.143 : Edge 8 => 7
#        0.002 : Edge 11 => 1
#        0.015 : Edge 16 => 17
#        0.015 : Edge 17 => 10
#        0.143 : Edge 18 => 19
#        0.143 : Edge 19 => 18
# Edge 7 => 2 :
#        0.197 : Edge 1 => 4
#        0.002 : Edge 1 => 11
#        0.197 : Edge 4 => 1
#        0.143 : Edge 7 => 8
#        0.143 : Edge 8 => 5
#        0.015 : Edge 10 => 17
#        0.002 : Edge 11 => 1
#        0.015 : Edge 17 => 10
#        0.143 : Edge 18 => 15
#        0.143 : Edge 19 => 18
# Edge 7 => 5 :
#        0.199 : Edge 1 => 11
#        0.197 : Edge 4 => 2
#        0.143 : Edge 7 => 8
#        0.143 : Edge 8 => 5
#        0.015 : Edge 10 => 17
#        0.002 : Edge 11 => 1
#        0.015 : Edge 17 => 4
#        0.143 : Edge 18 => 19
#        0.143 : Edge 19 => 18

# %%
solve_column_generation(instance)
# Out:
# Constructing empty model... done.
# Generating all paths...
#  done
# Valeur objective : 23.0
# Valeur objective : 22.999999999999968
# Column generation over. Number of columns : 595
# 1-element Vector{Mapping_Path_Fractional}:
#  Node placement of cost : 7.0
# 1 :
#        3 : 0.087
#        4 : 0.13
#        5 : 0.072
#        8 : 0.072
#        10 : 0.087
#        13 : 0.167
#        15 : 0.167
#        17 : 0.217
# 2 :
#        4 : 0.13
#        5 : 0.072
#        8 : 0.072
#        10 : 0.087
#        15 : 0.167
#        16 : 0.087
#        17 : 0.217
#        18 : 0.167
# 3 :
#        2 : 0.13
#        4 : 0.13
#        5 : 0.072
#        8 : 0.072
#        10 : 0.087
#        15 : 0.167
#        16 : 0.087
#        17 : 0.087
#        18 : 0.167
# 4 :
#        4 : 0.13
#        5 : 0.072
#        8 : 0.072
#        9 : 0.13
#        10 : 0.087
#        15 : 0.167
#        16 : 0.087
#        17 : 0.087
#        18 : 0.167
# 5 :
#        1 : 0.13
#        4 : 0.217
#        5 : 0.072
#        8 : 0.072
#        14 : 0.087
#        15 : 0.167
#        17 : 0.087
#        18 : 0.167
# 6 :
#        3 : 0.087
#        4 : 0.13
#        5 : 0.072
#        8 : 0.072
#        10 : 0.087
#        15 : 0.167
#        17 : 0.217
#        18 : 0.167
# 7 :
#        4 : 0.13
#        5 : 0.072
#        8 : 0.072
#        9 : 0.13
#        10 : 0.087
#        16 : 0.087
#        17 : 0.087
#        18 : 0.167
#        19 : 0.167
# Edge routing of cost: 16.0
# Edge 1 => 2 :
#        0.167 : Path(15, 18, Any[Edge 15 => 18], 1)
#        0.072 : Path(5, 8, Any[Edge 5 => 8], 1)
#        0.167 : Path(13, 15, Any[Edge 13 => 15], 1)
#        0.072 : Path(8, 5, Any[Edge 8 => 5], 1)
#        0.087 : Path(3, 16, Any[Edge 3 => 16], 1)
#        0.13 : Path(4, 17, Any[Edge 4 => 17], 1)
#        0.087 : Path(10, 17, Any[Edge 10 => 17], 1)
#        0.13 : Path(17, 4, Any[Edge 17 => 4], 1)
#        0.087 : Path(17, 10, Any[Edge 17 => 10], 1)
# Edge 1 => 3 :
#        0.167 : Path(15, 18, Any[Edge 15 => 18], 1)
#        0.072 : Path(5, 8, Any[Edge 5 => 8], 1)
#        0.167 : Path(13, 15, Any[Edge 13 => 15], 1)
#        0.072 : Path(8, 5, Any[Edge 8 => 5], 1)
#        0.087 : Path(3, 16, Any[Edge 3 => 16], 1)
#        0.13 : Path(4, 2, Any[Edge 4 => 2], 1)
#        0.087 : Path(10, 17, Any[Edge 10 => 17], 1)
#        0.13 : Path(17, 4, Any[Edge 17 => 4], 1)
#        0.087 : Path(17, 10, Any[Edge 17 => 10], 1)
# Edge 1 => 4 :
#        0.167 : Path(15, 18, Any[Edge 15 => 18], 1)
#        0.072 : Path(5, 8, Any[Edge 5 => 8], 1)
#        0.167 : Path(13, 15, Any[Edge 13 => 15], 1)
#        0.072 : Path(8, 5, Any[Edge 8 => 5], 1)
#        0.087 : Path(3, 16, Any[Edge 3 => 16], 1)
#        0.087 : Path(10, 17, Any[Edge 10 => 17], 1)
#        0.13 : Path(4, 9, Any[Edge 4 => 9], 1)
#        0.13 : Path(17, 4, Any[Edge 17 => 4], 1)
#        0.087 : Path(17, 10, Any[Edge 17 => 10], 1)
# Edge 2 => 3 :
#        0.167 : Path(15, 18, Any[Edge 15 => 18], 1)
#        0.087 : Path(10, 16, Any[Edge 10 => 16], 1)
#        0.072 : Path(5, 8, Any[Edge 5 => 8], 1)
#        0.072 : Path(8, 5, Any[Edge 8 => 5], 1)
#        0.167 : Path(18, 15, Any[Edge 18 => 15], 1)
#        0.13 : Path(4, 2, Any[Edge 4 => 2], 1)
#        0.087 : Path(16, 17, Any[Edge 16 => 17], 1)
#        0.13 : Path(17, 4, Any[Edge 17 => 4], 1)
#        0.087 : Path(17, 10, Any[Edge 17 => 10], 1)
# Edge 3 => 4 :
#        0.167 : Path(15, 18, Any[Edge 15 => 18], 1)
#        0.087 : Path(10, 16, Any[Edge 10 => 16], 1)
#        0.072 : Path(5, 8, Any[Edge 5 => 8], 1)
#        0.13 : Path(2, 4, Any[Edge 2 => 4], 1)
#        0.072 : Path(8, 5, Any[Edge 8 => 5], 1)
#        0.167 : Path(18, 15, Any[Edge 18 => 15], 1)
#        0.087 : Path(16, 17, Any[Edge 16 => 17], 1)
#        0.13 : Path(4, 9, Any[Edge 4 => 9], 1)
#        0.087 : Path(17, 10, Any[Edge 17 => 10], 1)
# Edge 3 => 7 :
#        0.167 : Path(15, 18, Any[Edge 15 => 18], 1)
#        0.087 : Path(10, 16, Any[Edge 10 => 16], 1)
#        0.072 : Path(5, 8, Any[Edge 5 => 8], 1)
#        0.13 : Path(2, 4, Any[Edge 2 => 4], 1)
#        0.072 : Path(8, 5, Any[Edge 8 => 5], 1)
#        0.167 : Path(18, 19, Any[Edge 18 => 19], 1)
#        0.087 : Path(16, 17, Any[Edge 16 => 17], 1)
#        0.13 : Path(4, 9, Any[Edge 4 => 9], 1)
#        0.087 : Path(17, 10, Any[Edge 17 => 10], 1)
# Edge 4 => 2 :
#        0.167 : Path(15, 18, Any[Edge 15 => 18], 1)
#        0.087 : Path(10, 16, Any[Edge 10 => 16], 1)
#        0.072 : Path(5, 8, Any[Edge 5 => 8], 1)
#        0.13 : Path(9, 4, Any[Edge 9 => 4], 1)
#        0.072 : Path(8, 5, Any[Edge 8 => 5], 1)
#        0.13 : Path(4, 17, Any[Edge 4 => 17], 1)
#        0.167 : Path(18, 15, Any[Edge 18 => 15], 1)
#        0.087 : Path(16, 17, Any[Edge 16 => 17], 1)
#        0.087 : Path(17, 10, Any[Edge 17 => 10], 1)
# Edge 4 => 5 :
#        0.167 : Path(15, 18, Any[Edge 15 => 18], 1)
#        0.072 : Path(5, 8, Any[Edge 5 => 8], 1)
#        0.13 : Path(9, 4, Any[Edge 9 => 4], 1)
#        0.087 : Path(16, 14, Any[Edge 16 => 14], 1)
#        0.072 : Path(8, 5, Any[Edge 8 => 5], 1)
#        0.13 : Path(4, 1, Any[Edge 4 => 1], 1)
#        0.167 : Path(18, 15, Any[Edge 18 => 15], 1)
#        0.087 : Path(10, 17, Any[Edge 10 => 17], 1)
#        0.087 : Path(17, 4, Any[Edge 17 => 4], 1)
# Edge 5 => 2 :
#        0.167 : Path(15, 18, Any[Edge 15 => 18], 1)
#        0.087 : Path(14, 16, Any[Edge 14 => 16], 1)
#        0.072 : Path(5, 8, Any[Edge 5 => 8], 1)
#        0.072 : Path(8, 5, Any[Edge 8 => 5], 1)
#        0.13 : Path(1, 4, Any[Edge 1 => 4], 1)
#        0.217 : Path(4, 17, Any[Edge 4 => 17], 1)
#        0.167 : Path(18, 15, Any[Edge 18 => 15], 1)
#        0.087 : Path(17, 10, Any[Edge 17 => 10], 1)
# Edge 5 => 4 :
#        0.167 : Path(15, 18, Any[Edge 15 => 18], 1)
#        0.087 : Path(14, 16, Any[Edge 14 => 16], 1)
#        0.072 : Path(5, 8, Any[Edge 5 => 8], 1)
#        0.072 : Path(8, 5, Any[Edge 8 => 5], 1)
#        0.13 : Path(1, 4, Any[Edge 1 => 4], 1)
#        0.087 : Path(4, 17, Any[Edge 4 => 17], 1)
#        0.167 : Path(18, 15, Any[Edge 18 => 15], 1)
#        0.13 : Path(4, 9, Any[Edge 4 => 9], 1)
#        0.087 : Path(17, 10, Any[Edge 17 => 10], 1)
# Edge 5 => 7 :
#        0.167 : Path(15, 18, Any[Edge 15 => 18], 1)
#        0.087 : Path(14, 16, Any[Edge 14 => 16], 1)
#        0.072 : Path(5, 8, Any[Edge 5 => 8], 1)
#        0.072 : Path(8, 5, Any[Edge 8 => 5], 1)
#        0.13 : Path(1, 4, Any[Edge 1 => 4], 1)
#        0.167 : Path(18, 19, Any[Edge 18 => 19], 1)
#        0.087 : Path(4, 17, Any[Edge 4 => 17], 1)
#        0.13 : Path(4, 9, Any[Edge 4 => 9], 1)
#        0.087 : Path(17, 10, Any[Edge 17 => 10], 1)
# Edge 6 => 2 :
#        0.167 : Path(15, 18, Any[Edge 15 => 18], 1)
#        0.072 : Path(5, 8, Any[Edge 5 => 8], 1)
#        0.072 : Path(8, 5, Any[Edge 8 => 5], 1)
#        0.087 : Path(3, 16, Any[Edge 3 => 16], 1)
#        0.13 : Path(4, 17, Any[Edge 4 => 17], 1)
#        0.167 : Path(18, 15, Any[Edge 18 => 15], 1)
#        0.087 : Path(10, 17, Any[Edge 10 => 17], 1)
#        0.13 : Path(17, 4, Any[Edge 17 => 4], 1)
#        0.087 : Path(17, 10, Any[Edge 17 => 10], 1)
# Edge 6 => 3 :
#        0.167 : Path(15, 18, Any[Edge 15 => 18], 1)
#        0.072 : Path(5, 8, Any[Edge 5 => 8], 1)
#        0.072 : Path(8, 5, Any[Edge 8 => 5], 1)
#        0.087 : Path(3, 16, Any[Edge 3 => 16], 1)
#        0.167 : Path(18, 15, Any[Edge 18 => 15], 1)
#        0.13 : Path(4, 2, Any[Edge 4 => 2], 1)
#        0.087 : Path(10, 17, Any[Edge 10 => 17], 1)
#        0.13 : Path(17, 4, Any[Edge 17 => 4], 1)
#        0.087 : Path(17, 10, Any[Edge 17 => 10], 1)
# Edge 6 => 7 :
#        0.167 : Path(15, 18, Any[Edge 15 => 18], 1)
#        0.072 : Path(5, 8, Any[Edge 5 => 8], 1)
#        0.072 : Path(8, 5, Any[Edge 8 => 5], 1)
#        0.087 : Path(3, 16, Any[Edge 3 => 16], 1)
#        0.167 : Path(18, 19, Any[Edge 18 => 19], 1)
#        0.087 : Path(10, 17, Any[Edge 10 => 17], 1)
#        0.13 : Path(4, 9, Any[Edge 4 => 9], 1)
#        0.13 : Path(17, 4, Any[Edge 17 => 4], 1)
#        0.087 : Path(17, 10, Any[Edge 17 => 10], 1)
# Edge 7 => 2 :
#        0.087 : Path(10, 16, Any[Edge 10 => 16], 1)
#        0.072 : Path(5, 8, Any[Edge 5 => 8], 1)
#        0.13 : Path(9, 4, Any[Edge 9 => 4], 1)
#        0.072 : Path(8, 5, Any[Edge 8 => 5], 1)
#        0.13 : Path(4, 17, Any[Edge 4 => 17], 1)
#        0.167 : Path(18, 15, Any[Edge 18 => 15], 1)
#        0.167 : Path(19, 18, Any[Edge 19 => 18], 1)
#        0.087 : Path(16, 17, Any[Edge 16 => 17], 1)
#        0.087 : Path(17, 10, Any[Edge 17 => 10], 1)
# Edge 7 => 5 :
#        0.072 : Path(5, 8, Any[Edge 5 => 8], 1)
#        0.13 : Path(9, 4, Any[Edge 9 => 4], 1)
#        0.087 : Path(16, 14, Any[Edge 16 => 14], 1)
#        0.072 : Path(8, 5, Any[Edge 8 => 5], 1)
#        0.13 : Path(4, 1, Any[Edge 4 => 1], 1)
#        0.167 : Path(18, 15, Any[Edge 18 => 15], 1)
#        0.167 : Path(19, 18, Any[Edge 19 => 18], 1)
#        0.087 : Path(10, 17, Any[Edge 10 => 17], 1)
#        0.087 : Path(17, 4, Any[Edge 17 => 4], 1)

# %%
solve_compact_integer(instance)
# Out:
# Constructing compact model...Version identifier: 22.1.1.0 | 2022-11-28 | 9160aff4d
# CPXPARAM_TimeLimit                               30
# CPXPARAM_MIP_Tolerances_Integrality              1e-08
# Tried aggregator 1 time.
# MIP Presolve eliminated 18 rows and 23 columns.
# MIP Presolve modified 1 coefficients.
# Reduced MIP has 349 rows, 702 columns, and 2556 nonzeros.
# Reduced MIP has 702 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (1.53 ticks)
# Probing time = 0.00 sec. (0.62 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# Reduced MIP has 349 rows, 702 columns, and 2556 nonzeros.
# Reduced MIP has 702 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (1.65 ticks)
# Probing time = 0.00 sec. (0.62 ticks)
# Clique table members: 233.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.00 sec. (1.38 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
#       0     0        7.0000    49                      7.0000       92
#       0     0        7.0000    49                    Cuts: 74      184
#       0     0       10.3214   113                    Cuts: 58      574
#       0     0       14.9013   119                    Cuts: 70      922
#       0     0       16.1997   177                ZeroHalf: 24     1121
# *     0+    0                           36.0000       16.1997            55.00%
#       0     0       17.6014   163       36.0000  ZeroHalf: 28     1386   51.11%
#       0     0       18.0669   186       36.0000  ZeroHalf: 23     1580   49.81%
#       0     0       18.4771   200       36.0000      Cuts: 24     1713   48.67%
#       0     0       18.6388   195       36.0000  ZeroHalf: 14     1846   48.23%
#       0     0       18.7880   172       36.0000  ZeroHalf: 13     1965   47.81%
#       0     0       18.9182   232       36.0000  ZeroHalf: 23     2093   47.45%
#       0     0       19.1191   131       36.0000       Cuts: 9     2199   46.89%
#       0     0       19.4718   231       36.0000  ZeroHalf: 32     2416   45.91%
# *     0+    0                           32.0000       19.4718            39.15%
#       0     0       19.6579   266       32.0000      Cuts: 18     2556   34.79%
#       0     0       19.7305   264       32.0000  ZeroHalf: 12     2680   34.79%
#       0     2       19.7305   264       32.0000       29.1667     2680    8.85%
# Elapsed time = 0.45 sec. (367.08 ticks, tree = 0.02 MB, solutions = 2)
#      82     6       21.1063   265       32.0000       29.1667    11443    8.85%
#     392    83        cutoff             32.0000       29.1667    39829    8.85%
#
# Clique cuts applied:  74
# Zero-half cuts applied:  87
# Lift and project cuts applied:  24
# Gomory fractional cuts applied:  7
#
# Root node processing (before b&c):
#   Real time             =    0.45 sec. (366.43 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.47 sec. (524.28 ticks)
#   Sync time (average)   =    0.15 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.92 sec. (890.71 ticks)
# 1-element Vector{Any}:
#  Node placement of cost :7
#        1 => 1
#        2 => 17
#        3 => 11
#        4 => 4
#        5 => 10
#        6 => 3
#        7 => 16
# Edge routing of cost: 25
#        Edge 1 => 2 => Path(1, 17, Any[Edge 1 => 4, Edge 4 => 17], 2)
#        Edge 1 => 3 => Path(1, 11, Any[Edge 1 => 11], 1)
#        Edge 1 => 4 => Path(1, 4, Any[Edge 1 => 4], 1)
#        Edge 2 => 3 => Path(17, 11, Any[Edge 17 => 4, Edge 4 => 1, Edge 1 => 11], 3)
#        Edge 3 => 4 => Path(11, 4, Any[Edge 11 => 1, Edge 1 => 4], 2)
#        Edge 3 => 7 => Path(11, 16, Any[Edge 11 => 3, Edge 3 => 16], 2)
#        Edge 4 => 2 => Path(4, 17, Any[Edge 4 => 17], 1)
#        Edge 4 => 5 => Path(4, 10, Any[Edge 4 => 17, Edge 17 => 10], 2)
#        Edge 5 => 2 => Path(10, 17, Any[Edge 10 => 17], 1)
#        Edge 5 => 4 => Path(10, 4, Any[Edge 10 => 17, Edge 17 => 4], 2)
#        Edge 5 => 7 => Path(10, 16, Any[Edge 10 => 16], 1)
#        Edge 6 => 2 => Path(3, 17, Any[Edge 3 => 16, Edge 16 => 17], 2)
#        Edge 6 => 3 => Path(3, 11, Any[Edge 3 => 11], 1)
#        Edge 6 => 7 => Path(3, 16, Any[Edge 3 => 16], 1)
#        Edge 7 => 2 => Path(16, 17, Any[Edge 16 => 17], 1)
#        Edge 7 => 5 => Path(16, 10, Any[Edge 16 => 17, Edge 17 => 10], 2)

# %%
solve_compact_integer(instance)
# Out:
# Constructing compact model...Version identifier: 22.1.1.0 | 2022-11-28 | 9160aff4d
# CPXPARAM_TimeLimit                               30
# CPXPARAM_MIP_Tolerances_Integrality              1e-08
# Tried aggregator 1 time.
# MIP Presolve eliminated 18 rows and 23 columns.
# MIP Presolve modified 1 coefficients.
# Reduced MIP has 349 rows, 702 columns, and 2556 nonzeros.
# Reduced MIP has 702 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (1.53 ticks)
# Probing time = 0.00 sec. (0.62 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# Reduced MIP has 349 rows, 702 columns, and 2556 nonzeros.
# Reduced MIP has 702 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (1.65 ticks)
# Probing time = 0.00 sec. (0.62 ticks)
# Clique table members: 233.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.00 sec. (1.38 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
#       0     0        7.0000    49                      7.0000       92
#       0     0        7.0000    49                    Cuts: 74      184
#       0     0       10.3214   113                    Cuts: 58      574
#       0     0       14.9013   119                    Cuts: 70      922
#       0     0       16.1997   177                ZeroHalf: 24     1121
# *     0+    0                           36.0000       16.1997            55.00%
#       0     0       17.6014   163       36.0000  ZeroHalf: 28     1386   51.11%
#       0     0       18.0669   186       36.0000  ZeroHalf: 23     1580   49.81%
#       0     0       18.4771   200       36.0000      Cuts: 24     1713   48.67%
#       0     0       18.6388   195       36.0000  ZeroHalf: 14     1846   48.23%
#       0     0       18.7880   172       36.0000  ZeroHalf: 13     1965   47.81%
#       0     0       18.9182   232       36.0000  ZeroHalf: 23     2093   47.45%
#       0     0       19.1191   131       36.0000       Cuts: 9     2199   46.89%
#       0     0       19.4718   231       36.0000  ZeroHalf: 32     2416   45.91%
# *     0+    0                           32.0000       19.4718            39.15%
#       0     0       19.6579   266       32.0000      Cuts: 18     2556   34.79%
#       0     0       19.7305   264       32.0000  ZeroHalf: 12     2680   34.79%
#       0     2       19.7305   264       32.0000       29.1667     2680    8.85%
# Elapsed time = 0.49 sec. (367.08 ticks, tree = 0.02 MB, solutions = 2)
#      82     6       21.1063   265       32.0000       29.1667    11443    8.85%
#     392    83        cutoff             32.0000       29.1667    39829    8.85%
#
# Clique cuts applied:  74
# Zero-half cuts applied:  87
# Lift and project cuts applied:  24
# Gomory fractional cuts applied:  7
#
# Root node processing (before b&c):
#   Real time             =    0.49 sec. (366.43 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.50 sec. (524.28 ticks)
#   Sync time (average)   =    0.15 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.99 sec. (890.71 ticks)
# 1-element Vector{Any}:
#  Node placement of cost :7
#        1 => 1
#        2 => 17
#        3 => 11
#        4 => 4
#        5 => 10
#        6 => 3
#        7 => 16
# Edge routing of cost: 25
#        Edge 1 => 2 => Path(1, 17, Any[Edge 1 => 4, Edge 4 => 17], 2)
#        Edge 1 => 3 => Path(1, 11, Any[Edge 1 => 11], 1)
#        Edge 1 => 4 => Path(1, 4, Any[Edge 1 => 4], 1)
#        Edge 2 => 3 => Path(17, 11, Any[Edge 17 => 4, Edge 4 => 1, Edge 1 => 11], 3)
#        Edge 3 => 4 => Path(11, 4, Any[Edge 11 => 1, Edge 1 => 4], 2)
#        Edge 3 => 7 => Path(11, 16, Any[Edge 11 => 3, Edge 3 => 16], 2)
#        Edge 4 => 2 => Path(4, 17, Any[Edge 4 => 17], 1)
#        Edge 4 => 5 => Path(4, 10, Any[Edge 4 => 17, Edge 17 => 10], 2)
#        Edge 5 => 2 => Path(10, 17, Any[Edge 10 => 17], 1)
#        Edge 5 => 4 => Path(10, 4, Any[Edge 10 => 17, Edge 17 => 4], 2)
#        Edge 5 => 7 => Path(10, 16, Any[Edge 10 => 16], 1)
#        Edge 6 => 2 => Path(3, 17, Any[Edge 3 => 16, Edge 16 => 17], 2)
#        Edge 6 => 3 => Path(3, 11, Any[Edge 3 => 11], 1)
#        Edge 6 => 7 => Path(3, 16, Any[Edge 3 => 16], 1)
#        Edge 7 => 2 => Path(16, 17, Any[Edge 16 => 17], 1)
#        Edge 7 => 5 => Path(16, 10, Any[Edge 16 => 17, Edge 17 => 10], 2)
