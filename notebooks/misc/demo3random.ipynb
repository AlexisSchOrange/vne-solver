# %%
using Revise
includet("utils/file_reader.jl")
includet("utils/some_data.jl")
includet("utils/utils_graph.jl")
includet("resolution/compact/compact_formulation.jl")
includet("resolution/path/path_generation.jl")
includet("utils/visu.jl")

# %%
instance = get_instance_from_folder("instances/random/1020")
# Out:
# InstanceVNE(Any[Meta graph based on a SimpleDiGraph{Int64} with vertex labels of type Int64, vertex metadata of type Dict, edge metadata of type Dict, graph metadata given by Dict(:type => "virtual", :name => "random"), and default weight 1.0], Meta graph based on a SimpleDiGraph{Int64} with vertex labels of type Int64, vertex metadata of type Dict, edge metadata of type Dict, graph metadata given by Dict(:type => "substrate", :name => "random"), and default weight 1.0)

# %%
visu_graph(instance.v_networks[1])

# %%
print_virtual(instance.v_networks[1])
# Out:
# Metagraph
# Node 1 with dem 5
# Node 2 with dem 3
# Node 3 with dem 3
# Node 4 with dem 3
# Node 5 with dem 5
# Node 6 with dem 4
# Node 7 with dem 4
# Node 8 with dem 5
# Node 9 with dem 5
# Node 10 with dem 6
# Edge Edge 1 => 4 with dem 2
# Edge Edge 1 => 5 with dem 1
# Edge Edge 1 => 7 with dem 1
# Edge Edge 2 => 6 with dem 2
# Edge Edge 3 => 2 with dem 2
# Edge Edge 4 => 1 with dem 1
# Edge Edge 5 => 4 with dem 1
# Edge Edge 5 => 7 with dem 1
# Edge Edge 5 => 8 with dem 2
# Edge Edge 6 => 4 with dem 1
# Edge Edge 6 => 8 with dem 1
# Edge Edge 6 => 9 with dem 2
# Edge Edge 7 => 2 with dem 1
# Edge Edge 7 => 3 with dem 2
# Edge Edge 7 => 5 with dem 1
# Edge Edge 8 => 3 with dem 2
# Edge Edge 8 => 4 with dem 1
# Edge Edge 9 => 7 with dem 2
# Edge Edge 9 => 8 with dem 2
# Edge Edge 10 => 5 with dem 2
# Edge Edge 10 => 6 with dem 1

# %%
visu_graph(instance.s_network)

# %%
print_substrate(instance.s_network)
# Out:
# Metagraph
# Node 1 with cap 7 and cost 7
# Node 2 with cap 12 and cost 7
# Node 3 with cap 7 and cost 9
# Node 4 with cap 13 and cost 8
# Node 5 with cap 12 and cost 6
# Node 6 with cap 9 and cost 10
# Node 7 with cap 11 and cost 10
# Node 8 with cap 11 and cost 8
# Node 9 with cap 11 and cost 8
# Node 10 with cap 8 and cost 8
# Node 11 with cap 13 and cost 7
# Node 12 with cap 9 and cost 7
# Node 13 with cap 13 and cost 8
# Node 14 with cap 7 and cost 7
# Node 15 with cap 9 and cost 7
# Edge Edge 2 => 4 with cap 10 and cost 6
# Edge Edge 2 => 9 with cap 10 and cost 8
# Edge Edge 2 => 11 with cap 10 and cost 10
# Edge Edge 3 => 5 with cap 9 and cost 8
# Edge Edge 3 => 11 with cap 10 and cost 6
# Edge Edge 3 => 15 with cap 9 and cost 7
# Edge Edge 4 => 3 with cap 12 and cost 10
# Edge Edge 4 => 8 with cap 13 and cost 7
# Edge Edge 4 => 9 with cap 12 and cost 6
# Edge Edge 4 => 10 with cap 11 and cost 5
# Edge Edge 5 => 2 with cap 8 and cost 8
# Edge Edge 5 => 12 with cap 9 and cost 6
# Edge Edge 6 => 11 with cap 14 and cost 7
# Edge Edge 7 => 2 with cap 12 and cost 6
# Edge Edge 7 => 3 with cap 8 and cost 6
# Edge Edge 7 => 6 with cap 9 and cost 6
# Edge Edge 7 => 9 with cap 7 and cost 5
# Edge Edge 7 => 11 with cap 9 and cost 7
# Edge Edge 7 => 15 with cap 14 and cost 10
# Edge Edge 8 => 1 with cap 8 and cost 5
# Edge Edge 8 => 3 with cap 13 and cost 9
# Edge Edge 9 => 1 with cap 13 and cost 9
# Edge Edge 9 => 4 with cap 7 and cost 5
# Edge Edge 9 => 7 with cap 11 and cost 9
# Edge Edge 10 => 1 with cap 14 and cost 5
# Edge Edge 10 => 4 with cap 8 and cost 10
# Edge Edge 10 => 7 with cap 14 and cost 6
# Edge Edge 11 => 1 with cap 12 and cost 7
# Edge Edge 11 => 4 with cap 9 and cost 10
# Edge Edge 11 => 14 with cap 11 and cost 7
# Edge Edge 12 => 7 with cap 12 and cost 7
# Edge Edge 12 => 8 with cap 10 and cost 9
# Edge Edge 13 => 5 with cap 8 and cost 5
# Edge Edge 14 => 2 with cap 13 and cost 9
# Edge Edge 14 => 4 with cap 8 and cost 5
# Edge Edge 14 => 5 with cap 12 and cost 6
# Edge Edge 14 => 9 with cap 10 and cost 7
# Edge Edge 14 => 10 with cap 10 and cost 6

# %%
solve_compact_fractional(instance)
# Out:
# Constructing compact model...CPLEX Error  3003: Not a mixed-integer problem.
# Version identifier: 22.1.1.0 | 2022-11-28 | 9160aff4d
# CPXPARAM_TimeLimit                               10
# CPXPARAM_MIP_Tolerances_Integrality              1e-08
# Tried aggregator 1 time.
# No LP presolve or aggregator reductions.
# Presolve time = 0.00 sec. (0.82 ticks)
# Initializing dual steep norms . . .
#
# Iteration log . . .
# Iteration:     1   Dual objective     =           289.000000
# Iteration:    62   Dual objective     =           289.000000
# Perturbation started.
# Iteration:   102   Dual objective     =           289.000000
# Removing perturbation.
# 1-element Vector{Any}:
#  Node placement of cost : 289.0
# 1 :
#        2 : 0.279
#        5 : 0.279
#        11 : 0.233
#        12 : 0.209
# 2 :
#        2 : 0.279
#        5 : 0.279
#        11 : 0.233
#        12 : 0.209
# 3 :
#        2 : 0.279
#        5 : 0.279
#        11 : 0.233
#        12 : 0.209
# 4 :
#        2 : 0.279
#        5 : 0.279
#        11 : 0.233
#        12 : 0.209
# 5 :
#        2 : 0.279
#        5 : 0.279
#        11 : 0.233
#        12 : 0.209
# 6 :
#        2 : 0.279
#        5 : 0.279
#        11 : 0.233
#        12 : 0.209
# 7 :
#        2 : 0.279
#        5 : 0.279
#        11 : 0.233
#        12 : 0.209
# 8 :
#        2 : 0.279
#        5 : 0.279
#        11 : 0.233
#        12 : 0.209
# 9 :
#        2 : 0.279
#        5 : 0.279
#        11 : 0.233
#        12 : 0.209
# 10 :
#        2 : 0.279
#        5 : 0.279
#        11 : 0.233
#        12 : 0.209
# Edge routing of cost: 0.0
# Edge 1 => 4 :
# Edge 1 => 5 :
# Edge 1 => 7 :
# Edge 2 => 6 :
# Edge 3 => 2 :
# Edge 4 => 1 :
# Edge 5 => 4 :
# Edge 5 => 7 :
# Edge 5 => 8 :
# Edge 6 => 4 :
# Edge 6 => 8 :
# Edge 6 => 9 :
# Edge 7 => 2 :
# Edge 7 => 3 :
# Edge 7 => 5 :
# Edge 8 => 3 :
# Edge 8 => 4 :
# Edge 9 => 7 :
# Edge 9 => 8 :
# Edge 10 => 5 :
# Edge 10 => 6 :

# %%
solve_compact_fractional(instance, true, true)
# Out:
# Constructing compact model...CPLEX Error  3003: Not a mixed-integer problem.
# Version identifier: 22.1.1.0 | 2022-11-28 | 9160aff4d
# CPXPARAM_TimeLimit                               10
# CPXPARAM_MIP_Tolerances_Integrality              1e-08
# Tried aggregator 1 time.
# LP Presolve eliminated 199 rows and 155 columns.
# Reduced LP has 824 rows, 793 columns, and 4691 nonzeros.
# Presolve time = 0.00 sec. (1.44 ticks)
# Initializing dual steep norms . . .
#
# Iteration log . . .
# Iteration:     1   Dual objective     =           289.000000
# Iteration:    70   Dual objective     =           320.000000
# Iteration:   141   Dual objective     =           347.500000
# Iteration:   216   Dual objective     =           390.500000
# Iteration:   296   Dual objective     =           434.000000
# Iteration:   380   Dual objective     =           476.000000
# Iteration:   449   Dual objective     =           494.666667
# Iteration:   511   Dual objective     =           507.007246
# Iteration:   573   Dual objective     =           514.600000
# Iteration:   635   Dual objective     =           518.735562
# Iteration:   697   Dual objective     =           522.363636
# Iteration:   759   Dual objective     =           525.303130
# Iteration:   821   Dual objective     =           527.174308
# Iteration:   883   Dual objective     =           528.158460
# Iteration:   945   Dual objective     =           528.725782
# Iteration:  1007   Dual objective     =           528.865711
# 1-element Vector{Any}:
#  Node placement of cost : 331.711
# 1 :
#        2 : 0.171
#        3 : 0.1
#        4 : 0.092
#        5 : 0.102
#        8 : 0.1
#        9 : 0.054
#        10 : 0.079
#        11 : 0.1
#        12 : 0.1
#        14 : 0.102
# 2 :
#        3 : 0.1
#        4 : 0.076
#        5 : 0.095
#        7 : 0.11
#        8 : 0.1
#        9 : 0.14
#        10 : 0.079
#        11 : 0.1
#        12 : 0.1
#        14 : 0.1
# 3 :
#        2 : 0.027
#        3 : 0.1
#        4 : 0.106
#        5 : 0.1
#        7 : 0.081
#        8 : 0.1
#        9 : 0.076
#        10 : 0.11
#        11 : 0.1
#        12 : 0.1
#        14 : 0.1
# 4 :
#        2 : 0.002
#        3 : 0.1
#        4 : 0.133
#        5 : 0.1
#        7 : 0.079
#        8 : 0.1
#        9 : 0.092
#        10 : 0.094
#        11 : 0.1
#        12 : 0.1
#        14 : 0.1
# 5 :
#        2 : 0.002
#        3 : 0.1
#        4 : 0.105
#        5 : 0.102
#        7 : 0.179
#        9 : 0.133
#        10 : 0.079
#        11 : 0.1
#        12 : 0.1
#        14 : 0.1
# 6 :
#        2 : 0.067
#        3 : 0.1
#        4 : 0.14
#        5 : 0.1
#        7 : 0.179
#        9 : 0.081
#        10 : 0.059
#        11 : 0.1
#        12 : 0.075
#        14 : 0.1
# 7 :
#        2 : 0.002
#        3 : 0.1
#        4 : 0.133
#        5 : 0.1
#        7 : 0.179
#        9 : 0.105
#        10 : 0.081
#        11 : 0.1
#        12 : 0.1
#        14 : 0.1
# 8 :
#        2 : 0.025
#        3 : 0.075
#        4 : 0.133
#        5 : 0.1
#        7 : 0.133
#        8 : 0.046
#        9 : 0.106
#        10 : 0.081
#        11 : 0.1
#        12 : 0.1
#        14 : 0.1
# 9 :
#        2 : 0.073
#        3 : 0.1
#        4 : 0.081
#        5 : 0.1
#        7 : 0.059
#        8 : 0.075
#        9 : 0.133
#        10 : 0.133
#        11 : 0.1
#        12 : 0.046
#        14 : 0.1
# 10 :
#        2 : 0.221
#        3 : 0.1
#        5 : 0.102
#        8 : 0.1
#        11 : 0.1
#        12 : 0.179
#        13 : 0.1
#        14 : 0.098
# Edge routing of cost: 197.156
# Edge 1 => 4 :
#        0.079 : Edge 2 => 4
#        0.092 : Edge 2 => 9
#        0.1 : Edge 3 => 11
#        0.092 : Edge 4 => 10
#        0.002 : Edge 5 => 2
#        0.1 : Edge 5 => 12
#        0.1 : Edge 8 => 3
#        0.054 : Edge 9 => 4
#        0.079 : Edge 10 => 7
#        0.1 : Edge 11 => 14
#        0.1 : Edge 12 => 8
#        0.1 : Edge 14 => 5
#        0.002 : Edge 14 => 10
# Edge 1 => 5 :
#        0.051 : Edge 2 => 4
#        0.121 : Edge 2 => 9
#        0.1 : Edge 3 => 11
#        0.013 : Edge 4 => 9
#        0.079 : Edge 4 => 10
#        0.002 : Edge 5 => 2
#        0.1 : Edge 5 => 12
#        0.1 : Edge 8 => 3
#        0.054 : Edge 9 => 4
#        0.079 : Edge 10 => 7
#        0.1 : Edge 11 => 14
#        0.1 : Edge 12 => 7
#        0.102 : Edge 14 => 5
# Edge 1 => 7 :
#        0.079 : Edge 2 => 4
#        0.092 : Edge 2 => 9
#        0.1 : Edge 3 => 11
#        0.011 : Edge 4 => 9
#        0.081 : Edge 4 => 10
#        0.002 : Edge 5 => 2
#        0.1 : Edge 5 => 12
#        0.1 : Edge 8 => 3
#        0.054 : Edge 9 => 4
#        0.079 : Edge 10 => 7
#        0.1 : Edge 11 => 14
#        0.1 : Edge 12 => 7
#        0.1 : Edge 14 => 5
#        0.002 : Edge 14 => 9
# Edge 2 => 6 :
#        0.1 : Edge 3 => 11
#        0.017 : Edge 4 => 9
#        0.059 : Edge 4 => 10
#        0.021 : Edge 5 => 2
#        0.075 : Edge 5 => 12
#        0.046 : Edge 7 => 2
#        0.063 : Edge 7 => 9
#        0.1 : Edge 8 => 3
#        0.14 : Edge 9 => 4
#        0.079 : Edge 10 => 7
#        0.1 : Edge 11 => 14
#        0.1 : Edge 12 => 7
#        0.1 : Edge 14 => 5
# Edge 3 => 2 :
#        0.027 : Edge 2 => 9
#        0.1 : Edge 3 => 11
#        0.027 : Edge 4 => 9
#        0.079 : Edge 4 => 10
#        0.1 : Edge 5 => 12
#        0.081 : Edge 7 => 9
#        0.1 : Edge 8 => 3
#        0.076 : Edge 9 => 4
#        0.11 : Edge 10 => 7
#        0.1 : Edge 11 => 14
#        0.1 : Edge 12 => 8
#        0.095 : Edge 14 => 5
#        0.005 : Edge 14 => 9
# Edge 4 => 1 :
#        0.002 : Edge 2 => 11
#        0.002 : Edge 3 => 5
#        0.098 : Edge 3 => 11
#        0.054 : Edge 4 => 9
#        0.079 : Edge 4 => 10
#        0.1 : Edge 5 => 12
#        0.171 : Edge 7 => 2
#        0.002 : Edge 7 => 11
#        0.1 : Edge 8 => 3
#        0.092 : Edge 9 => 4
#        0.094 : Edge 10 => 7
#        0.102 : Edge 11 => 14
#        0.1 : Edge 12 => 8
#        0.1 : Edge 14 => 5
# Edge 5 => 4 :
#        0.002 : Edge 2 => 9
#        0.1 : Edge 3 => 11
#        0.011 : Edge 4 => 9
#        0.094 : Edge 4 => 10
#        0.002 : Edge 5 => 2
#        0.1 : Edge 5 => 12
#        0.1 : Edge 7 => 3
#        0.079 : Edge 7 => 9
#        0.133 : Edge 9 => 4
#        0.079 : Edge 10 => 7
#        0.1 : Edge 11 => 14
#        0.1 : Edge 12 => 8
#        0.1 : Edge 14 => 5
# Edge 5 => 7 :
#        0.002 : Edge 2 => 9
#        0.1 : Edge 3 => 11
#        0.024 : Edge 4 => 9
#        0.081 : Edge 4 => 10
#        0.002 : Edge 5 => 2
#        0.1 : Edge 5 => 12
#        0.1 : Edge 7 => 3
#        0.079 : Edge 7 => 9
#        0.133 : Edge 9 => 4
#        0.079 : Edge 10 => 7
#        0.1 : Edge 11 => 14
#        0.1 : Edge 12 => 7
#        0.1 : Edge 14 => 5
# Edge 5 => 8 :
#        0.002 : Edge 2 => 9
#        0.1 : Edge 3 => 11
#        0.024 : Edge 4 => 9
#        0.081 : Edge 4 => 10
#        0.002 : Edge 5 => 2
#        0.1 : Edge 5 => 12
#        0.024 : Edge 7 => 2
#        0.075 : Edge 7 => 3
#        0.081 : Edge 7 => 9
#        0.133 : Edge 9 => 4
#        0.079 : Edge 10 => 7
#        0.1 : Edge 11 => 14
#        0.054 : Edge 12 => 7
#        0.046 : Edge 12 => 8
#        0.1 : Edge 14 => 5
# Edge 6 => 4 :
#        0.052 : Edge 2 => 4
#        0.014 : Edge 2 => 9
#        0.1 : Edge 3 => 11
#        0.046 : Edge 4 => 8
#        0.094 : Edge 4 => 10
#        0.1 : Edge 5 => 12
#        0.002 : Edge 7 => 2
#        0.1 : Edge 7 => 3
#        0.078 : Edge 7 => 9
#        0.081 : Edge 9 => 4
#        0.059 : Edge 10 => 7
#        0.1 : Edge 11 => 14
#        0.021 : Edge 12 => 7
#        0.054 : Edge 12 => 8
#        0.1 : Edge 14 => 5
# Edge 6 => 8 :
#        0.052 : Edge 2 => 4
#        0.014 : Edge 2 => 9
#        0.1 : Edge 3 => 11
#        0.046 : Edge 4 => 8
#        0.013 : Edge 4 => 9
#        0.081 : Edge 4 => 10
#        0.1 : Edge 5 => 12
#        0.025 : Edge 7 => 2
#        0.075 : Edge 7 => 3
#        0.079 : Edge 7 => 9
#        0.081 : Edge 9 => 4
#        0.059 : Edge 10 => 7
#        0.1 : Edge 11 => 14
#        0.075 : Edge 12 => 7
#        0.1 : Edge 14 => 5
# Edge 6 => 9 :
#        0.067 : Edge 2 => 9
#        0.1 : Edge 3 => 11
#        0.006 : Edge 4 => 9
#        0.133 : Edge 4 => 10
#        0.054 : Edge 5 => 2
#        0.046 : Edge 5 => 12
#        0.019 : Edge 7 => 2
#        0.1 : Edge 7 => 3
#        0.06 : Edge 7 => 9
#        0.081 : Edge 9 => 4
#        0.059 : Edge 10 => 7
#        0.1 : Edge 11 => 14
#        0.075 : Edge 12 => 8
#        0.1 : Edge 14 => 5
# Edge 7 => 2 :
#        0.002 : Edge 2 => 9
#        0.1 : Edge 3 => 11
#        0.054 : Edge 4 => 9
#        0.079 : Edge 4 => 10
#        0.1 : Edge 5 => 12
#        0.1 : Edge 7 => 3
#        0.079 : Edge 7 => 9
#        0.076 : Edge 9 => 4
#        0.029 : Edge 9 => 7
#        0.081 : Edge 10 => 7
#        0.1 : Edge 11 => 14
#        0.1 : Edge 12 => 8
#        0.095 : Edge 14 => 5
#        0.005 : Edge 14 => 9
# Edge 7 => 3 :
#        0.002 : Edge 2 => 4
#        0.1 : Edge 3 => 11
#        0.024 : Edge 4 => 9
#        0.11 : Edge 4 => 10
#        0.1 : Edge 5 => 12
#        0.027 : Edge 7 => 2
#        0.1 : Edge 7 => 3
#        0.052 : Edge 7 => 9
#        0.105 : Edge 9 => 4
#        0.081 : Edge 10 => 7
#        0.1 : Edge 11 => 14
#        0.1 : Edge 12 => 8
#        0.1 : Edge 14 => 5
# Edge 7 => 5 :
#        0.002 : Edge 2 => 9
#        0.002 : Edge 3 => 5
#        0.098 : Edge 3 => 11
#        0.054 : Edge 4 => 9
#        0.079 : Edge 4 => 10
#        0.1 : Edge 5 => 12
#        0.002 : Edge 7 => 2
#        0.1 : Edge 7 => 3
#        0.078 : Edge 7 => 9
#        0.002 : Edge 7 => 11
#        0.105 : Edge 9 => 4
#        0.081 : Edge 10 => 7
#        0.1 : Edge 11 => 14
#        0.1 : Edge 12 => 7
#        0.1 : Edge 14 => 5
# Edge 8 => 3 :
#        0.025 : Edge 2 => 11
#        0.075 : Edge 3 => 11
#        0.024 : Edge 4 => 9
#        0.11 : Edge 4 => 10
#        0.1 : Edge 5 => 12
#        0.027 : Edge 7 => 2
#        0.054 : Edge 7 => 3
#        0.052 : Edge 7 => 9
#        0.046 : Edge 8 => 3
#        0.106 : Edge 9 => 4
#        0.081 : Edge 10 => 7
#        0.1 : Edge 11 => 14
#        0.1 : Edge 12 => 8
#        0.1 : Edge 14 => 5
# Edge 8 => 4 :
#        0.025 : Edge 2 => 4
#        0.075 : Edge 3 => 11
#        0.04 : Edge 4 => 9
#        0.094 : Edge 4 => 10
#        0.1 : Edge 5 => 12
#        0.002 : Edge 7 => 2
#        0.054 : Edge 7 => 3
#        0.052 : Edge 7 => 9
#        0.025 : Edge 7 => 11
#        0.046 : Edge 8 => 3
#        0.106 : Edge 9 => 4
#        0.002 : Edge 10 => 4
#        0.079 : Edge 10 => 7
#        0.1 : Edge 11 => 14
#        0.1 : Edge 12 => 8
#        0.1 : Edge 14 => 5
# Edge 9 => 7 :
#        0.073 : Edge 2 => 9
#        0.1 : Edge 3 => 11
#        0.081 : Edge 4 => 10
#        0.1 : Edge 5 => 12
#        0.002 : Edge 7 => 2
#        0.025 : Edge 7 => 3
#        0.032 : Edge 7 => 9
#        0.075 : Edge 8 => 3
#        0.133 : Edge 9 => 4
#        0.133 : Edge 10 => 7
#        0.1 : Edge 11 => 14
#        0.046 : Edge 12 => 7
#        0.1 : Edge 14 => 5
# Edge 9 => 8 :
#        0.073 : Edge 2 => 9
#        0.1 : Edge 3 => 11
#        0.081 : Edge 4 => 10
#        0.1 : Edge 5 => 12
#        0.025 : Edge 7 => 2
#        0.033 : Edge 7 => 9
#        0.075 : Edge 8 => 3
#        0.133 : Edge 9 => 4
#        0.133 : Edge 10 => 7
#        0.1 : Edge 11 => 14
#        0.046 : Edge 12 => 8
#        0.1 : Edge 14 => 5
# Edge 10 => 5 :
#        0.087 : Edge 2 => 4
#        0.133 : Edge 2 => 9
#        0.1 : Edge 3 => 11
#        0.002 : Edge 5 => 2
#        0.1 : Edge 5 => 12
#        0.1 : Edge 8 => 3
#        0.1 : Edge 11 => 14
#        0.179 : Edge 12 => 7
#        0.1 : Edge 13 => 5
#        0.017 : Edge 14 => 4
#        0.002 : Edge 14 => 5
#        0.079 : Edge 14 => 10
# Edge 10 => 6 :
#        0.14 : Edge 2 => 4
#        0.081 : Edge 2 => 9
#        0.1 : Edge 3 => 11
#        0.027 : Edge 5 => 2
#        0.075 : Edge 5 => 12
#        0.1 : Edge 8 => 3
#        0.1 : Edge 11 => 14
#        0.179 : Edge 12 => 7
#        0.1 : Edge 13 => 5
#        0.04 : Edge 14 => 2
#        0.059 : Edge 14 => 10

# %%
solve_column_generation(instance)
# Out:
# Constructing empty model... done.
# Generating all paths...
#  done
# Valeur objective : 528.8666666666666
# Column generation over. Number of columns : 3570
# 1-element Vector{Mapping_Path_Fractional}:
#  Node placement of cost : 331.719
# 1 :
#        2 : 0.17
#        3 : 0.1
#        4 : 0.092
#        5 : 0.102
#        8 : 0.1
#        9 : 0.056
#        10 : 0.079
#        11 : 0.1
#        12 : 0.1
#        14 : 0.102
# 2 :
#        3 : 0.1
#        4 : 0.076
#        5 : 0.095
#        7 : 0.11
#        8 : 0.1
#        9 : 0.14
#        10 : 0.079
#        11 : 0.1
#        12 : 0.1
#        14 : 0.1
# 3 :
#        2 : 0.027
#        3 : 0.1
#        4 : 0.106
#        5 : 0.1
#        7 : 0.081
#        8 : 0.1
#        9 : 0.076
#        10 : 0.11
#        11 : 0.1
#        12 : 0.1
#        14 : 0.1
# 4 :
#        2 : 0.002
#        3 : 0.1
#        4 : 0.133
#        5 : 0.1
#        7 : 0.079
#        8 : 0.1
#        9 : 0.092
#        10 : 0.094
#        11 : 0.1
#        12 : 0.1
#        14 : 0.1
# 5 :
#        2 : 0.002
#        3 : 0.1
#        4 : 0.105
#        5 : 0.102
#        7 : 0.179
#        9 : 0.133
#        10 : 0.079
#        11 : 0.1
#        12 : 0.1
#        14 : 0.1
# 6 :
#        2 : 0.067
#        3 : 0.1
#        4 : 0.14
#        5 : 0.1
#        7 : 0.179
#        9 : 0.081
#        10 : 0.059
#        11 : 0.1
#        12 : 0.075
#        14 : 0.1
# 7 :
#        2 : 0.002
#        3 : 0.1
#        4 : 0.133
#        5 : 0.1
#        7 : 0.179
#        9 : 0.105
#        10 : 0.081
#        11 : 0.1
#        12 : 0.1
#        14 : 0.1
# 8 :
#        2 : 0.025
#        3 : 0.075
#        4 : 0.133
#        5 : 0.1
#        7 : 0.133
#        8 : 0.046
#        9 : 0.106
#        10 : 0.081
#        11 : 0.1
#        12 : 0.1
#        14 : 0.1
# 9 :
#        2 : 0.073
#        3 : 0.1
#        4 : 0.081
#        5 : 0.1
#        7 : 0.059
#        8 : 0.075
#        9 : 0.133
#        10 : 0.133
#        11 : 0.1
#        12 : 0.046
#        14 : 0.1
# 10 :
#        2 : 0.221
#        3 : 0.1
#        5 : 0.102
#        8 : 0.1
#        11 : 0.1
#        12 : 0.179
#        13 : 0.1
#        14 : 0.098
# Edge routing of cost: 197.148
# Edge 1 => 4 :
#        0.002 : Path(14, 10, Any[Edge 14 => 10], 6)
#        0.092 : Path(4, 10, Any[Edge 4 => 10], 5)
#        0.079 : Path(10, 7, Any[Edge 10 => 7], 6)
#        0.078 : Path(2, 4, Any[Edge 2 => 4], 6)
#        0.002 : Path(5, 2, Any[Edge 5 => 2], 8)
#        0.092 : Path(2, 9, Any[Edge 2 => 9], 8)
#        0.1 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.1 : Path(8, 3, Any[Edge 8 => 3], 9)
#        0.1 : Path(14, 5, Any[Edge 14 => 5], 6)
#        0.056 : Path(9, 4, Any[Edge 9 => 4], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.1 : Path(3, 11, Any[Edge 3 => 11], 6)
#        0.1 : Path(12, 8, Any[Edge 12 => 8], 9)
# Edge 1 => 5 :
#        0.1 : Path(12, 7, Any[Edge 12 => 7], 7)
#        0.079 : Path(4, 10, Any[Edge 4 => 10], 5)
#        0.079 : Path(10, 7, Any[Edge 10 => 7], 6)
#        0.013 : Path(4, 9, Any[Edge 4 => 9], 6)
#        0.049 : Path(2, 4, Any[Edge 2 => 4], 6)
#        0.002 : Path(5, 2, Any[Edge 5 => 2], 8)
#        0.121 : Path(2, 9, Any[Edge 2 => 9], 8)
#        0.1 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.1 : Path(8, 3, Any[Edge 8 => 3], 9)
#        0.102 : Path(14, 5, Any[Edge 14 => 5], 6)
#        0.056 : Path(9, 4, Any[Edge 9 => 4], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.1 : Path(3, 11, Any[Edge 3 => 11], 6)
# Edge 1 => 7 :
#        0.1 : Path(12, 7, Any[Edge 12 => 7], 7)
#        0.081 : Path(4, 10, Any[Edge 4 => 10], 5)
#        0.079 : Path(10, 7, Any[Edge 10 => 7], 6)
#        0.011 : Path(4, 9, Any[Edge 4 => 9], 6)
#        0.002 : Path(14, 4, Any[Edge 14 => 4], 5)
#        0.076 : Path(2, 4, Any[Edge 2 => 4], 6)
#        0.002 : Path(5, 2, Any[Edge 5 => 2], 8)
#        0.094 : Path(2, 9, Any[Edge 2 => 9], 8)
#        0.1 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.1 : Path(8, 3, Any[Edge 8 => 3], 9)
#        0.1 : Path(14, 5, Any[Edge 14 => 5], 6)
#        0.056 : Path(9, 4, Any[Edge 9 => 4], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.1 : Path(3, 11, Any[Edge 3 => 11], 6)
# Edge 2 => 6 :
#        0.1 : Path(12, 7, Any[Edge 12 => 7], 7)
#        0.059 : Path(4, 10, Any[Edge 4 => 10], 5)
#        0.079 : Path(10, 7, Any[Edge 10 => 7], 6)
#        0.046 : Path(7, 2, Any[Edge 7 => 2], 6)
#        0.017 : Path(4, 9, Any[Edge 4 => 9], 6)
#        0.021 : Path(5, 2, Any[Edge 5 => 2], 8)
#        0.075 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.1 : Path(8, 3, Any[Edge 8 => 3], 9)
#        0.1 : Path(14, 5, Any[Edge 14 => 5], 6)
#        0.063 : Path(7, 9, Any[Edge 7 => 9], 5)
#        0.14 : Path(9, 4, Any[Edge 9 => 4], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.1 : Path(3, 11, Any[Edge 3 => 11], 6)
# Edge 3 => 2 :
#        0.005 : Path(14, 10, Any[Edge 14 => 10], 6)
#        0.075 : Path(4, 10, Any[Edge 4 => 10], 5)
#        0.11 : Path(10, 7, Any[Edge 10 => 7], 6)
#        0.032 : Path(4, 9, Any[Edge 4 => 9], 6)
#        0.027 : Path(2, 9, Any[Edge 2 => 9], 8)
#        0.1 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.1 : Path(8, 3, Any[Edge 8 => 3], 9)
#        0.095 : Path(14, 5, Any[Edge 14 => 5], 6)
#        0.081 : Path(7, 9, Any[Edge 7 => 9], 5)
#        0.076 : Path(9, 4, Any[Edge 9 => 4], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.1 : Path(3, 11, Any[Edge 3 => 11], 6)
#        0.1 : Path(12, 8, Any[Edge 12 => 8], 9)
# Edge 4 => 1 :
#        0.002 : Path(7, 11, Any[Edge 7 => 11], 7)
#        0.079 : Path(4, 10, Any[Edge 4 => 10], 5)
#        0.076 : Path(7, 2, Any[Edge 7 => 2], 6)
#        0.054 : Path(4, 9, Any[Edge 4 => 9], 6)
#        0.094 : Path(10, 2, Any[Edge 10 => 7, Edge 7 => 2], 12)
#        0.002 : Path(2, 9, Any[Edge 2 => 9], 8)
#        0.002 : Path(3, 5, Any[Edge 3 => 5], 8)
#        0.1 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.1 : Path(8, 3, Any[Edge 8 => 3], 9)
#        0.1 : Path(14, 5, Any[Edge 14 => 5], 6)
#        0.002 : Path(7, 14, Any[Edge 7 => 11, Edge 11 => 14], 14)
#        0.092 : Path(9, 4, Any[Edge 9 => 4], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.098 : Path(3, 11, Any[Edge 3 => 11], 6)
#        0.1 : Path(12, 8, Any[Edge 12 => 8], 9)
# Edge 5 => 4 :
#        0.094 : Path(4, 10, Any[Edge 4 => 10], 5)
#        0.079 : Path(10, 7, Any[Edge 10 => 7], 6)
#        0.011 : Path(4, 9, Any[Edge 4 => 9], 6)
#        0.002 : Path(5, 2, Any[Edge 5 => 2], 8)
#        0.002 : Path(2, 9, Any[Edge 2 => 9], 8)
#        0.1 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.1 : Path(14, 5, Any[Edge 14 => 5], 6)
#        0.1 : Path(7, 3, Any[Edge 7 => 3], 6)
#        0.079 : Path(7, 9, Any[Edge 7 => 9], 5)
#        0.133 : Path(9, 4, Any[Edge 9 => 4], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.1 : Path(3, 11, Any[Edge 3 => 11], 6)
#        0.1 : Path(12, 8, Any[Edge 12 => 8], 9)
# Edge 5 => 7 :
#        0.1 : Path(12, 7, Any[Edge 12 => 7], 7)
#        0.081 : Path(4, 10, Any[Edge 4 => 10], 5)
#        0.079 : Path(10, 7, Any[Edge 10 => 7], 6)
#        0.024 : Path(4, 9, Any[Edge 4 => 9], 6)
#        0.002 : Path(5, 2, Any[Edge 5 => 2], 8)
#        0.002 : Path(2, 9, Any[Edge 2 => 9], 8)
#        0.1 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.1 : Path(14, 5, Any[Edge 14 => 5], 6)
#        0.1 : Path(7, 3, Any[Edge 7 => 3], 6)
#        0.079 : Path(7, 9, Any[Edge 7 => 9], 5)
#        0.133 : Path(9, 4, Any[Edge 9 => 4], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.1 : Path(3, 11, Any[Edge 3 => 11], 6)
# Edge 5 => 8 :
#        0.054 : Path(12, 7, Any[Edge 12 => 7], 7)
#        0.081 : Path(4, 10, Any[Edge 4 => 10], 5)
#        0.079 : Path(10, 7, Any[Edge 10 => 7], 6)
#        0.024 : Path(7, 2, Any[Edge 7 => 2], 6)
#        0.024 : Path(4, 9, Any[Edge 4 => 9], 6)
#        0.002 : Path(5, 2, Any[Edge 5 => 2], 8)
#        0.002 : Path(2, 9, Any[Edge 2 => 9], 8)
#        0.1 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.1 : Path(14, 5, Any[Edge 14 => 5], 6)
#        0.075 : Path(7, 3, Any[Edge 7 => 3], 6)
#        0.081 : Path(7, 9, Any[Edge 7 => 9], 5)
#        0.133 : Path(9, 4, Any[Edge 9 => 4], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.1 : Path(3, 11, Any[Edge 3 => 11], 6)
#        0.046 : Path(12, 8, Any[Edge 12 => 8], 9)
# Edge 6 => 4 :
#        0.021 : Path(12, 7, Any[Edge 12 => 7], 7)
#        0.094 : Path(4, 10, Any[Edge 4 => 10], 5)
#        0.059 : Path(10, 7, Any[Edge 10 => 7], 6)
#        0.046 : Path(4, 8, Any[Edge 4 => 8], 7)
#        0.002 : Path(7, 2, Any[Edge 7 => 2], 6)
#        0.052 : Path(2, 4, Any[Edge 2 => 4], 6)
#        0.014 : Path(2, 9, Any[Edge 2 => 9], 8)
#        0.1 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.1 : Path(14, 5, Any[Edge 14 => 5], 6)
#        0.1 : Path(7, 3, Any[Edge 7 => 3], 6)
#        0.078 : Path(7, 9, Any[Edge 7 => 9], 5)
#        0.081 : Path(9, 4, Any[Edge 9 => 4], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.1 : Path(3, 11, Any[Edge 3 => 11], 6)
#        0.054 : Path(12, 8, Any[Edge 12 => 8], 9)
# Edge 6 => 8 :
#        0.075 : Path(12, 7, Any[Edge 12 => 7], 7)
#        0.081 : Path(4, 10, Any[Edge 4 => 10], 5)
#        0.059 : Path(10, 7, Any[Edge 10 => 7], 6)
#        0.046 : Path(4, 8, Any[Edge 4 => 8], 7)
#        0.025 : Path(7, 2, Any[Edge 7 => 2], 6)
#        0.013 : Path(4, 9, Any[Edge 4 => 9], 6)
#        0.052 : Path(2, 4, Any[Edge 2 => 4], 6)
#        0.014 : Path(2, 9, Any[Edge 2 => 9], 8)
#        0.1 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.1 : Path(14, 5, Any[Edge 14 => 5], 6)
#        0.075 : Path(7, 3, Any[Edge 7 => 3], 6)
#        0.079 : Path(7, 9, Any[Edge 7 => 9], 5)
#        0.081 : Path(9, 4, Any[Edge 9 => 4], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.1 : Path(3, 11, Any[Edge 3 => 11], 6)
# Edge 6 => 9 :
#        0.133 : Path(4, 10, Any[Edge 4 => 10], 5)
#        0.059 : Path(10, 7, Any[Edge 10 => 7], 6)
#        0.019 : Path(7, 2, Any[Edge 7 => 2], 6)
#        0.006 : Path(4, 9, Any[Edge 4 => 9], 6)
#        0.054 : Path(5, 2, Any[Edge 5 => 2], 8)
#        0.067 : Path(2, 9, Any[Edge 2 => 9], 8)
#        0.046 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.1 : Path(14, 5, Any[Edge 14 => 5], 6)
#        0.1 : Path(7, 3, Any[Edge 7 => 3], 6)
#        0.06 : Path(7, 9, Any[Edge 7 => 9], 5)
#        0.081 : Path(9, 4, Any[Edge 9 => 4], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.1 : Path(3, 11, Any[Edge 3 => 11], 6)
#        0.075 : Path(12, 8, Any[Edge 12 => 8], 9)
# Edge 7 => 2 :
#        0.005 : Path(14, 10, Any[Edge 14 => 10], 6)
#        0.075 : Path(4, 10, Any[Edge 4 => 10], 5)
#        0.081 : Path(10, 7, Any[Edge 10 => 7], 6)
#        0.059 : Path(4, 9, Any[Edge 4 => 9], 6)
#        0.002 : Path(2, 9, Any[Edge 2 => 9], 8)
#        0.1 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.095 : Path(14, 5, Any[Edge 14 => 5], 6)
#        0.1 : Path(7, 3, Any[Edge 7 => 3], 6)
#        0.029 : Path(9, 7, Any[Edge 9 => 7], 9)
#        0.079 : Path(7, 9, Any[Edge 7 => 9], 5)
#        0.076 : Path(9, 4, Any[Edge 9 => 4], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.1 : Path(3, 11, Any[Edge 3 => 11], 6)
#        0.1 : Path(12, 8, Any[Edge 12 => 8], 9)
# Edge 7 => 3 :
#        0.11 : Path(4, 10, Any[Edge 4 => 10], 5)
#        0.081 : Path(10, 7, Any[Edge 10 => 7], 6)
#        0.027 : Path(7, 2, Any[Edge 7 => 2], 6)
#        0.024 : Path(4, 9, Any[Edge 4 => 9], 6)
#        0.002 : Path(2, 4, Any[Edge 2 => 4], 6)
#        0.1 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.1 : Path(14, 5, Any[Edge 14 => 5], 6)
#        0.1 : Path(7, 3, Any[Edge 7 => 3], 6)
#        0.052 : Path(7, 9, Any[Edge 7 => 9], 5)
#        0.105 : Path(9, 4, Any[Edge 9 => 4], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.1 : Path(3, 11, Any[Edge 3 => 11], 6)
#        0.1 : Path(12, 8, Any[Edge 12 => 8], 9)
# Edge 7 => 5 :
#        0.098 : Path(12, 7, Any[Edge 12 => 7], 7)
#        0.002 : Path(12, 2, Any[Edge 12 => 7, Edge 7 => 2], 13)
#        0.002 : Path(2, 11, Any[Edge 2 => 11], 10)
#        0.079 : Path(4, 10, Any[Edge 4 => 10], 5)
#        0.081 : Path(10, 7, Any[Edge 10 => 7], 6)
#        0.054 : Path(4, 9, Any[Edge 4 => 9], 6)
#        0.002 : Path(3, 5, Any[Edge 3 => 5], 8)
#        0.1 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.1 : Path(14, 5, Any[Edge 14 => 5], 6)
#        0.1 : Path(7, 3, Any[Edge 7 => 3], 6)
#        0.079 : Path(7, 9, Any[Edge 7 => 9], 5)
#        0.105 : Path(9, 4, Any[Edge 9 => 4], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.098 : Path(3, 11, Any[Edge 3 => 11], 6)
# Edge 8 => 3 :
#        0.025 : Path(2, 11, Any[Edge 2 => 11], 10)
#        0.11 : Path(4, 10, Any[Edge 4 => 10], 5)
#        0.081 : Path(10, 7, Any[Edge 10 => 7], 6)
#        0.027 : Path(7, 2, Any[Edge 7 => 2], 6)
#        0.024 : Path(4, 9, Any[Edge 4 => 9], 6)
#        0.1 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.046 : Path(8, 3, Any[Edge 8 => 3], 9)
#        0.1 : Path(14, 5, Any[Edge 14 => 5], 6)
#        0.054 : Path(7, 3, Any[Edge 7 => 3], 6)
#        0.052 : Path(7, 9, Any[Edge 7 => 9], 5)
#        0.106 : Path(9, 4, Any[Edge 9 => 4], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.075 : Path(3, 11, Any[Edge 3 => 11], 6)
#        0.1 : Path(12, 8, Any[Edge 12 => 8], 9)
# Edge 8 => 4 :
#        0.002 : Path(10, 4, Any[Edge 10 => 4], 10)
#        0.025 : Path(7, 11, Any[Edge 7 => 11], 7)
#        0.094 : Path(4, 10, Any[Edge 4 => 10], 5)
#        0.079 : Path(10, 7, Any[Edge 10 => 7], 6)
#        0.002 : Path(7, 2, Any[Edge 7 => 2], 6)
#        0.04 : Path(4, 9, Any[Edge 4 => 9], 6)
#        0.025 : Path(2, 4, Any[Edge 2 => 4], 6)
#        0.1 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.046 : Path(8, 3, Any[Edge 8 => 3], 9)
#        0.1 : Path(14, 5, Any[Edge 14 => 5], 6)
#        0.054 : Path(7, 3, Any[Edge 7 => 3], 6)
#        0.052 : Path(7, 9, Any[Edge 7 => 9], 5)
#        0.106 : Path(9, 4, Any[Edge 9 => 4], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.075 : Path(3, 11, Any[Edge 3 => 11], 6)
#        0.1 : Path(12, 8, Any[Edge 12 => 8], 9)
# Edge 9 => 7 :
#        0.046 : Path(12, 7, Any[Edge 12 => 7], 7)
#        0.081 : Path(4, 10, Any[Edge 4 => 10], 5)
#        0.133 : Path(10, 7, Any[Edge 10 => 7], 6)
#        0.002 : Path(7, 2, Any[Edge 7 => 2], 6)
#        0.073 : Path(2, 9, Any[Edge 2 => 9], 8)
#        0.1 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.075 : Path(8, 3, Any[Edge 8 => 3], 9)
#        0.1 : Path(14, 5, Any[Edge 14 => 5], 6)
#        0.025 : Path(7, 3, Any[Edge 7 => 3], 6)
#        0.032 : Path(7, 9, Any[Edge 7 => 9], 5)
#        0.133 : Path(9, 4, Any[Edge 9 => 4], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.1 : Path(3, 11, Any[Edge 3 => 11], 6)
# Edge 9 => 8 :
#        0.081 : Path(4, 10, Any[Edge 4 => 10], 5)
#        0.133 : Path(10, 7, Any[Edge 10 => 7], 6)
#        0.025 : Path(7, 2, Any[Edge 7 => 2], 6)
#        0.073 : Path(2, 9, Any[Edge 2 => 9], 8)
#        0.1 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.075 : Path(8, 3, Any[Edge 8 => 3], 9)
#        0.1 : Path(14, 5, Any[Edge 14 => 5], 6)
#        0.033 : Path(7, 9, Any[Edge 7 => 9], 5)
#        0.133 : Path(9, 4, Any[Edge 9 => 4], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.1 : Path(3, 11, Any[Edge 3 => 11], 6)
#        0.046 : Path(12, 8, Any[Edge 12 => 8], 9)
# Edge 10 => 5 :
#        0.179 : Path(12, 7, Any[Edge 12 => 7], 7)
#        0.079 : Path(14, 10, Any[Edge 14 => 10], 6)
#        0.017 : Path(14, 4, Any[Edge 14 => 4], 5)
#        0.087 : Path(2, 4, Any[Edge 2 => 4], 6)
#        0.002 : Path(5, 2, Any[Edge 5 => 2], 8)
#        0.133 : Path(2, 9, Any[Edge 2 => 9], 8)
#        0.1 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.1 : Path(8, 3, Any[Edge 8 => 3], 9)
#        0.002 : Path(14, 5, Any[Edge 14 => 5], 6)
#        0.1 : Path(13, 5, Any[Edge 13 => 5], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.1 : Path(3, 11, Any[Edge 3 => 11], 6)
# Edge 10 => 6 :
#        0.179 : Path(12, 7, Any[Edge 12 => 7], 7)
#        0.059 : Path(14, 10, Any[Edge 14 => 10], 6)
#        0.14 : Path(2, 4, Any[Edge 2 => 4], 6)
#        0.027 : Path(5, 2, Any[Edge 5 => 2], 8)
#        0.081 : Path(2, 9, Any[Edge 2 => 9], 8)
#        0.075 : Path(5, 12, Any[Edge 5 => 12], 6)
#        0.1 : Path(8, 3, Any[Edge 8 => 3], 9)
#        0.1 : Path(13, 5, Any[Edge 13 => 5], 5)
#        0.1 : Path(11, 14, Any[Edge 11 => 14], 7)
#        0.1 : Path(3, 11, Any[Edge 3 => 11], 6)
#        0.04 : Path(14, 2, Any[Edge 14 => 2], 9)

# %%
solve_compact_integer(instance, true, true)
# Out:
# Constructing compact model...Version identifier: 22.1.1.0 | 2022-11-28 | 9160aff4d
# CPXPARAM_TimeLimit                               30
# CPXPARAM_MIP_Tolerances_Integrality              1e-08
# Tried aggregator 1 time.
# MIP Presolve eliminated 211 rows and 155 columns.
# MIP Presolve modified 132 coefficients.
# Reduced MIP has 812 rows, 793 columns, and 4571 nonzeros.
# Reduced MIP has 793 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (3.10 ticks)
# Found incumbent of value 1053.000000 after 0.01 sec. (8.11 ticks)
# Probing time = 0.00 sec. (0.91 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# Reduced MIP has 812 rows, 793 columns, and 4571 nonzeros.
# Reduced MIP has 793 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (2.58 ticks)
# Probing time = 0.00 sec. (0.91 ticks)
# Clique table members: 192.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.02 sec. (39.37 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         1053.0000        0.0000           100.00%
#       0     0      528.8667   356     1053.0000      528.8667     1027   49.78%
# *     0+    0                          932.0000      528.8667            43.25%
#       0     0      536.8399   416      932.0000      Cuts: 25     1437   42.40%
#       0     0      537.6823   419      932.0000   ZeroHalf: 3     1554   42.31%
#       0     0      538.1900   427      932.0000   ZeroHalf: 1     1680   42.25%
# *     0+    0                          909.0000      538.1900            40.79%
# *     0+    0                          706.0000      538.1900            23.77%
# *     0+    0                          599.0000      538.1900            10.15%
#       0     0        cutoff            599.0000      599.0000     1680    0.00%
# Elapsed time = 0.47 sec. (430.30 ticks, tree = 0.01 MB, solutions = 5)
#
# Zero-half cuts applied:  8
# Lift and project cuts applied:  1
# Gomory fractional cuts applied:  1
#
# Root node processing (before b&c):
#   Real time             =    0.47 sec. (430.37 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.47 sec. (430.37 ticks)
# 1-element Vector{Any}:
#  Node placement of cost :337
#        1 => 12
#        2 => 11
#        3 => 3
#        4 => 8
#        5 => 9
#        6 => 14
#        7 => 7
#        8 => 4
#        9 => 10
#        10 => 2
# Edge routing of cost: 262
#        Edge 1 => 4 => Path(12, 8, Any[Edge 12 => 8], 9)
#        Edge 1 => 5 => Path(12, 9, Any[Edge 12 => 7, Edge 7 => 9], 12)
#        Edge 1 => 7 => Path(12, 7, Any[Edge 12 => 7], 7)
#        Edge 2 => 6 => Path(11, 14, Any[Edge 11 => 14], 7)
#        Edge 3 => 2 => Path(3, 11, Any[Edge 3 => 11], 6)
#        Edge 4 => 1 => Path(8, 12, Any[Edge 8 => 3, Edge 3 => 5, Edge 5 => 12], 23)
#        Edge 5 => 4 => Path(9, 8, Any[Edge 9 => 4, Edge 4 => 8], 12)
#        Edge 5 => 7 => Path(9, 7, Any[Edge 9 => 7], 9)
#        Edge 5 => 8 => Path(9, 4, Any[Edge 9 => 4], 5)
#        Edge 6 => 4 => Path(14, 8, Any[Edge 14 => 4, Edge 4 => 8], 12)
#        Edge 6 => 8 => Path(14, 4, Any[Edge 14 => 4], 5)
#        Edge 6 => 9 => Path(14, 10, Any[Edge 14 => 10], 6)
#        Edge 7 => 2 => Path(7, 11, Any[Edge 7 => 11], 7)
#        Edge 7 => 3 => Path(7, 3, Any[Edge 7 => 3], 6)
#        Edge 7 => 5 => Path(7, 9, Any[Edge 7 => 9], 5)
#        Edge 8 => 3 => Path(4, 3, Any[Edge 4 => 3], 10)
#        Edge 8 => 4 => Path(4, 8, Any[Edge 4 => 8], 7)
#        Edge 9 => 7 => Path(10, 7, Any[Edge 10 => 7], 6)
#        Edge 9 => 8 => Path(10, 4, Any[Edge 10 => 4], 10)
#        Edge 10 => 5 => Path(2, 9, Any[Edge 2 => 9], 8)
#        Edge 10 => 6 => Path(2, 14, Any[Edge 2 => 11, Edge 11 => 14], 17)
