# %%
using Revise
includet("../../../importall.jl")

# %%
instance = get_instance_from_folder("../../../instances/undirected/tests/vndemo/Bandcon/")
visu_graph(instance.s_network)

# %%
visu_graph(instance.v_networks[1])

# %%
solve_undir_compact_dir(instance)
# Out:
# Constructing compact model... done.
# Starting solving...
# Version identifier: 22.1.1.0 | 2022-11-28 | 9160aff4d
# CPXPARAM_MIP_Display                             3
# CPXPARAM_TimeLimit                               30
# Tried aggregator 2 times.
# MIP Presolve eliminated 2072 rows and 0 columns.
# Aggregator did 952 substitutions.
# Reduced MIP has 1133 rows, 1225 columns, and 6734 nonzeros.
# Reduced MIP has 1225 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (12.19 ticks)
# Found incumbent of value 58.000000 after 0.02 sec. (19.30 ticks)
# Probing time = 0.00 sec. (1.79 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# Reduced MIP has 1133 rows, 1225 columns, and 6734 nonzeros.
# Reduced MIP has 1225 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (3.81 ticks)
# Probing time = 0.00 sec. (1.79 ticks)
# Clique table members: 126.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.04 sec. (45.58 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                           58.0000        0.0000           100.00%
# Found incumbent of value 58.000000 after 0.07 sec. (74.75 ticks)
# *     0+    0                           45.0000        0.0000           100.00%
# Found incumbent of value 45.000000 after 0.07 sec. (74.77 ticks)
# *     0+    0                           44.0000        0.0000           100.00%
# Found incumbent of value 44.000000 after 0.07 sec. (74.78 ticks)
# *     0+    0                           35.0000        0.0000           100.00%
# Found incumbent of value 35.000000 after 0.07 sec. (74.80 ticks)
# *     0+    0                           34.0000        0.0000           100.00%
# Found incumbent of value 34.000000 after 0.07 sec. (74.81 ticks)
# *     0+    0                           33.0000        0.0000           100.00%
# Found incumbent of value 33.000000 after 0.07 sec. (74.83 ticks)
# *     0+    0                           31.0000        0.0000           100.00%
# Found incumbent of value 31.000000 after 0.07 sec. (74.84 ticks)
# *     0+    0                           28.0000        0.0000           100.00%
# Found incumbent of value 28.000000 after 0.07 sec. (74.85 ticks)
# *     0+    0                           26.0000        0.0000           100.00%
# Found incumbent of value 26.000000 after 0.07 sec. (74.87 ticks)
# *     0+    0                           25.0000        0.0000           100.00%
# Found incumbent of value 25.000000 after 0.07 sec. (74.88 ticks)
#       0     0       17.0000   411       25.0000       17.0000     1042   32.00%
# *     0+    0                           21.0000       17.0000            19.05%
# Found incumbent of value 21.000000 after 0.31 sec. (299.94 ticks)
# Detecting symmetries...
#       0     2       17.0000   332       21.0000       17.0000     1042   19.05%
# Elapsed time = 0.41 sec. (381.71 ticks, tree = 0.02 MB, solutions = 11)
#     200     5       18.7500   119       21.0000       17.8333    14994   15.08%
#                                                   ZeroHalf: 1
# done. Solving state: OPTIMAL, obj value: 21.0, bound value: 21.0
#
# Zero-half cuts applied:  1
#
# Root node processing (before b&c):
#   Real time             =    0.41 sec. (381.08 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.25 sec. (274.84 ticks)
#   Sync time (average)   =    0.14 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.66 sec. (655.92 ticks)
# 1-element Vector{Any}:
#  Node placement of cost :0
#        1 => 18
#        2 => 19
#        3 => 12
#        4 => 8
#        5 => 10
#        6 => 7
#        7 => 20
#        8 => 2
#        9 => 11
#        10 => 15
#        11 => 6
#        12 => 16
#        13 => 9
# Edge routing of cost: 21
#        Edge 1 => 2 => Path(18, 19, Any[Edge 18 => 19], 1)
#        Edge 1 => 4 => Path(18, 8, Any[Edge 8 => 18], 1)
#        Edge 1 => 10 => Path(18, 15, Any[Edge 15 => 18], 1)
#        Edge 2 => 3 => Path(19, 12, Any[Edge 12 => 19], 1)
#        Edge 4 => 5 => Path(8, 10, Any[Edge 8 => 10], 1)
#        Edge 4 => 6 => Path(8, 7, Any[Edge 7 => 8], 1)
#        Edge 4 => 7 => Path(8, 20, Any[Edge 8 => 20], 1)
#        Edge 5 => 6 => Path(10, 7, Any[Edge 8 => 10, Edge 7 => 8], 2)
#        Edge 7 => 8 => Path(20, 2, Any[Edge 2 => 20], 1)
#        Edge 7 => 9 => Path(20, 11, Any[Edge 11 => 20], 1)
#        Edge 7 => 10 => Path(20, 15, Any[Edge 18 => 20, Edge 15 => 18], 2)
#        Edge 10 => 11 => Path(15, 6, Any[Edge 6 => 15], 1)
#        Edge 10 => 12 => Path(15, 16, Any[Edge 15 => 16], 1)
#        Edge 10 => 13 => Path(15, 9, Any[Edge 9 => 15], 1)
#        Edge 11 => 12 => Path(6, 16, Any[Edge 6 => 15, Edge 15 => 16], 2)
#        Edge 11 => 13 => Path(6, 9, Any[Edge 6 => 9], 1)
#        Edge 12 => 13 => Path(16, 9, Any[Edge 15 => 16, Edge 9 => 15], 2)
